# %% [markdown]
# เขียนโปรแกรมรับ input จากผู้ใช้ 1 ตัว แปลงให้เป็น int และตรวจ
# สอบว่าเป็นเลขคู่หรือเลขคี่

# %%
a = int(input('ใส่ค่าที่เป็นจำนวนเต็ม ='))
# Out:
# ใส่ค่าที่เป็นจำนวนเต็ม =0

# %%
if a%2 == 0 and a !=0 :
  print('เลขคู่')
elif a%2 != 0:
  print('เลขคี่')
if a==0:
  print('เลขศูนย์')
# Out:
# เลขศูนย์
