# %% [markdown]
# เขียนโปรแกรมรับค่า input ที่เป็น integer มาหนึ่งตัว ตรวจสอบว่า
# เลขนั้นหาร 7 ลงตัวหรือไม่

# %%
a = int(input('รับค่าจำนวนเต็ม '))
if a%7 == 0:
  print('หาร 7 ลงตัว')
else:
  print('หาร 7 ไม่ลงตัว')
# Out:
# รับค่าจำนวนเต็ม 50
# หาร 7 ไม่ลงตัว
