# %% [markdown]
# เขียนโปรแกรมรับค่า input 2 ตัว ในรูปแบบ float โดยให้ตัวแรกเป็น
# ตัวตั้ง ตัวที่สองเป็นตัวหาร

# %%
a = float(input('ใส่ค่าตัวตั้ง ='))
# Out:
# ใส่ค่าตัวตั้ง =13

# %%
b = 0
while b == 0:
  b = float(input('ใส่ค่าตัวหาร ='))
# Out:
# ใส่ค่าตัวหาร =12

# %%
print('ผลหารคือ {}'.format(a/b))
# Out:
# ผลหารคือ 1.0833333333333333
