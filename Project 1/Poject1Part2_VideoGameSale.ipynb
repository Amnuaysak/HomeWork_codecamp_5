# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#1 Import ไฟล์ vgsales เช็คข้อมูลเบื้องต้น
url = 'https://raw.githubusercontent.com/Amnuaysak/HomeWork_codecamp_5/master/vgsales.csv'
df = pd.read_csv(url)
df1=df #สร้างมาไว้ใชัดัดแปลง
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %%
#2 สุ่มอ่านข้อมูล 10 แถว หัว 5 แถว และท้าย 10 แถว
pd.concat([df.head(5),df.tail(5)])
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [10 rows x 11 columns]

# %%
#3 หา Top 10 Platform ยอดฮิต พร้อมระบุจำนวน
df2 = df['Global_Sales'].groupby(df['Platform']).sum().sort_values()[::-1].head(10) #df ของ platform ที่มียอดขายสูงสุดอันดับที่ 1 ถึง 10 
df2
# Out:
# Platform
# PS2     1255.64
# X360     979.96
# PS3      957.84
# Wii      926.71
# DS       822.49
# PS       730.66
# GBA      318.50
# PSP      296.28
# PS4      278.10
# PC       258.82
# Name: Global_Sales, dtype: float64

# %%
#4 หา Bottom 10 Platform ยอดฮิต พร้อมระบุจำนวน
df2 = df['Global_Sales'].groupby(df['Platform']).sum().sort_values().head(10) #df ของ platform ที่มียอดขายต่ำสุดอันดับที่ 1 ถึง 10 
df2
# Out:
# Platform
# PCFX     0.03
# GG       0.04
# 3DO      0.10
# TG16     0.16
# WS       1.42
# NG       1.44
# SCD      1.87
# DC      15.97
# GEN     28.36
# SAT     33.59
# Name: Global_Sales, dtype: float64

# %%
#5 หา Top 10 Platform ชนิดของเกมส์ยอดฮิต พร้อมระบุจำนวน
mostHitGenre = df['Genre'].value_counts().head() #หาอันดับ 1 ของชนิดของเกมส์ยอดฮิต คือ เกมส์ชนิด Action
mostHitGenre
#df[df['Genre']==mostHitGenre]

#df2 = df['Global_Sales'].groupby(df['']).sum().sort_values().head(10)
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Name: Genre, dtype: int64

# %%
df[(df['Genre']=='Action')]['Platform'].value_counts().head(10)
# Out:
# PS3     380
# PS2     348
# DS      343
# X360    324
# Wii     238
# PSP     222
# 3DS     182
# GBA     167
# PC      165
# PS      157
# Name: Platform, dtype: int64

# %%
#6 หา Bottom 10 Platform ชนิดของเกมส์ยอดฮิต พร้อมระบุจำนวน
df[(df['Genre']=='Action')]['Platform'].value_counts().tail(10)
# Out:
# XOne    68
# WiiU    63
# 2600    61
# N64     38
# NES     13
# SNES    12
# GB       6
# DC       3
# GEN      3
# SAT      3
# Name: Platform, dtype: int64

# %%
#7 หารายละเอียดเกมส์ GTA V ภาคต่างๆ ทั้งหมด
df[df['Name'].str.match('Grand Theft Auto')]
# Out:
#         Rank  ... Global_Sales
# 16        17  ...        21.40
# 17        18  ...        20.81
# 23        24  ...        16.38
# 24        25  ...        16.15
# 38        39  ...        13.10
# 44        45  ...        11.98
# 51        52  ...        11.02
# 56        57  ...        10.57
# 90        91  ...         7.72
# 197      198  ...         5.08
# 198      199  ...         5.08
# 360      361  ...         3.54
# 388      389  ...         3.42
# 684      686  ...         2.32
# 873      875  ...         1.95
# 1441    1443  ...         1.35
# 1896    1898  ...         1.08
# 1902    1904  ...         1.08
# 2120    2122  ...         0.98
# 2138    2140  ...         0.97
# 2357    2359  ...         0.88
# 6905    6907  ...         0.24
# 9827    9829  ...         0.12
# 10379  10381  ...         0.11
# 13732  13734  ...         0.04
# 16093  16096  ...         0.01
#
# [26 rows x 11 columns]

# %%
#8 หาจำนวนเกมส์ที่มีชื่อซ้ำกันทั้งหมด
df1 = df['Name'].value_counts() #ค่า value มากกว่า 1 จึงแปลว่า ซ้ำ
df1[df1.values>1]
# Out:
# Need for Speed: Most Wanted     12
# LEGO Marvel Super Heroes         9
# Madden NFL 07                    9
# FIFA 14                          9
# Ratatouille                      9
#                                 ..
# Razor Freestyle Scooter          2
# The Terminator: Dawn of Fate     2
# Showtime Championship Boxing     2
# nail'd                           2
# Constantine                      2
# Name: Name, Length: 2775, dtype: int64

# %%
#9 หาจำนวนเกมส์ที่มีชื่อและ Platform ซ้ำกันทั้งหมด
df.head(20).groupby('Name')['Platform'].count()
# Out:
# Name
# Brain Age: Train Your Brain in Minutes a Day    1
# Duck Hunt                                       1
# Grand Theft Auto V                              1
# Grand Theft Auto: San Andreas                   1
# Kinect Adventures!                              1
# Mario Kart DS                                   1
# Mario Kart Wii                                  1
# New Super Mario Bros.                           1
# New Super Mario Bros. Wii                       1
# Nintendogs                                      1
# Pokemon Gold/Pokemon Silver                     1
# Pokemon Red/Pokemon Blue                        1
# Super Mario Bros.                               1
# Super Mario World                               1
# Tetris                                          1
# Wii Fit                                         1
# Wii Fit Plus                                    1
# Wii Play                                        1
# Wii Sports                                      1
# ...

# %%
df.head(20)
# Out:
#     Rank  ... Global_Sales
# 0      1  ...        82.74
# 1      2  ...        40.24
# 2      3  ...        35.82
# 3      4  ...        33.00
# 4      5  ...        31.37
# 5      6  ...        30.26
# 6      7  ...        30.01
# 7      8  ...        29.02
# 8      9  ...        28.62
# 9     10  ...        28.31
# 10    11  ...        24.76
# 11    12  ...        23.42
# 12    13  ...        23.10
# 13    14  ...        22.72
# 14    15  ...        22.00
# 15    16  ...        21.82
# 16    17  ...        21.40
# 17    18  ...        20.81
# 18    19  ...        20.61
# 19    20  ...        20.22
#
# [20 rows x 11 columns]

# %%
#10 หาจำนวนเกมส์ที่มีชื่อและ Platform ซ้ำกันทั้งหมด
df['Platform'].value_counts().head(10) #Platform ที่มีชื่อซ้ำกันมากที่สุด
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# Name: Platform, dtype: int64

# %%
df['Name'].value_counts().head(10) #เกมส์ ที่มีชื่อซ้ำกันมากที่สุด
# Out:
# Need for Speed: Most Wanted                12
# Ratatouille                                 9
# Madden NFL 07                               9
# FIFA 14                                     9
# LEGO Marvel Super Heroes                    9
# LEGO Jurassic World                         8
# Terraria                                    8
# LEGO Star Wars II: The Original Trilogy     8
# Angry Birds Star Wars                       8
# Madden NFL 08                               8
# Name: Name, dtype: int64

# %%
#11 หารายได้ทั้งหมดเกมส์ FIFA 15
df[df['Name'].str.match('FIFA 15')]['Global_Sales'].sum().round(2)
# Out:
# 19.02

# %%
#12 หารายได้ทั้งหมดของเกมส์ GTA V ในญี่ปุ่น
df[df['Name'].str.match('Grand Theft Auto V')]['JP_Sales'].sum().round(2)
# Out:
# 1.39

# %%
#13 สร้าง DF ที่ให้ index เป็นรายชื่อของเกมส์ที่มีซ้ำ และ Column เป็นจำนวนที่มีซ้ำ ไม่นับที่เป็น Unique
df1 = df['Name'].value_counts() #ค่า value มากกว่า 1 จึงแปลว่า ซ้ำ
df1 = df1[df1.values>1]
df1
# Out:
# Need for Speed: Most Wanted     12
# LEGO Marvel Super Heroes         9
# Madden NFL 07                    9
# FIFA 14                          9
# Ratatouille                      9
#                                 ..
# Razor Freestyle Scooter          2
# The Terminator: Dawn of Fate     2
# Showtime Championship Boxing     2
# nail'd                           2
# Constantine                      2
# Name: Name, Length: 2775, dtype: int64

# %%
#14 สร้าง DF ที่มี index เป็นชื่อบริษัท และเรียงลำดับตามรายได้รวมจากมากไปน้อย
df.groupby('Publisher')['Global_Sales'].sum().sort_values()[::-1]
# Out:
# Publisher
# Nintendo                       1786.56
# Electronic Arts                1110.32
# Activision                      727.46
# Sony Computer Entertainment     607.50
# Ubisoft                         474.72
#                                 ...
# Takuyo                            0.01
# Otomate                           0.01
# Epic Games                        0.01
# Inti Creates                      0.01
# Interworks Unlimited, Inc.        0.01
# Name: Global_Sales, Length: 578, dtype: float64

# %%
#15 จงสร้าง DF ที่บรรจุเกมส์ Series Call of duty ทั้งหมด
df[df['Name'].str.match('Call')]
# Out:
#         Rank                                  Name  ... Other_Sales  Global_Sales
# 29        30        Call of Duty: Modern Warfare 3  ...        1.32         14.76
# 31        32               Call of Duty: Black Ops  ...        1.13         14.64
# 33        34             Call of Duty: Black Ops 3  ...        2.31         14.24
# 34        35            Call of Duty: Black Ops II  ...        2.52         14.03
# 35        36            Call of Duty: Black Ops II  ...        1.12         13.73
# ...      ...                                   ...  ...         ...           ...
# 12639  12641      Call of Duty: The War Collection  ...        0.00          0.06
# 14219  14222        Call of Juarez: Bound in Blood  ...        0.01          0.03
# 15598  15601  Call of Duty: Modern Warfare Trilogy  ...        0.00          0.02
# 15804  15807  Call of Duty: Modern Warfare Trilogy  ...        0.00          0.02
# ...

# %%
#16 จงหาว่า Call of Duty ภาคใดใน PC มีรายสูงสุดในยุโรป 5 อันดับแรก
df[df['Name'].str.match('Call')].sort_values('EU_Sales')[::-1]
# Out:
#         Rank  ... Global_Sales
# 34        35  ...        14.03
# 37        38  ...        13.46
# 33        34  ...        14.24
# 40        41  ...        12.73
# 35        36  ...        13.73
# ...      ...  ...          ...
# 15804  15807  ...         0.02
# 12458  12460  ...         0.06
# 15598  15601  ...         0.02
# 16010  16013  ...         0.01
# 12639  12641  ...         0.06
#
# [72 rows x 11 columns]

# %%
#17 จงหาว่า Platform ใด มียอดขายรวมสูงสุดในยุโรป
df.groupby('Platform')['EU_Sales'].sum().sort_values()[::-1].head(1)
# Out:
# Platform
# PS3    343.71
# Name: EU_Sales, dtype: float64

# %%
#18 จงหาว่าเกมส์ประเภทใดมียอดขายเฉลี่ยสูงสุดในภูมิภาคอื่นๆรอบโลก
df.groupby('Genre')['Other_Sales'].sum().sort_values()[::-1].head(1)
# Out:
# Genre
# Action    187.38
# Name: Other_Sales, dtype: float64

# %%
#19 สร้าง Bar Plot โดยให้แกน X เป็น Platform และ Y เป็นยอดขายทั่วโลก
plt.figure(figsize=(28,8))
sns.barplot(x=df['Platform'],y=df['Global_Sales'])

# %%
#20 สร้าง Pie Chart หาส่วนแบ่งทางการตลาดของ 5 บริษัทแรกที่มีรายได้มากที่สุด
df1 = df['Publisher'].value_counts().head(5)
#df1
labels = df1.index
plt.figure(figsize=(8,8))
plt.pie(df1.values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff2ce9df048>,
# ...
#  [Text(0.7284615972984712, 0.8242230894978375, 'Electronic Arts'),
#   Text(-0.7372045521181685, 0.8164125478802068, 'Activision'),
#   Text(-1.0297821885660117, -0.38671519767419993, 'Namco Bandai Games'),
#   Text(-0.05480316124034704, -1.0986339761349386, 'Ubisoft'),
#   Text(0.953717977239218, -0.548107671804304, 'Konami Digital Entertainment')])

# %%
#21 สร้าง Count Plot นับข้อมูลประเภทของเกมส์
plt.figure(figsize=(28,8))
df1 = df['Genre'].value_counts()
sns.countplot(x=df['Genre'],data=df)

# %%
#22 สร้าง Bar plot Top 5 รายได้ทั่วโลกของ Call of Duty ภาคต่างๆใน Xbox
df3=df[df['Name'].str.match('Call')].sort_values('Global_Sales')[::-1]
df3
# Out:
#         Rank                                  Name  ... Other_Sales  Global_Sales
# 29        30        Call of Duty: Modern Warfare 3  ...        1.32         14.76
# 31        32               Call of Duty: Black Ops  ...        1.13         14.64
# 33        34             Call of Duty: Black Ops 3  ...        2.31         14.24
# 34        35            Call of Duty: Black Ops II  ...        2.52         14.03
# 35        36            Call of Duty: Black Ops II  ...        1.12         13.73
# ...      ...                                   ...  ...         ...           ...
# 12639  12641      Call of Duty: The War Collection  ...        0.00          0.06
# 14219  14222        Call of Juarez: Bound in Blood  ...        0.01          0.03
# 15598  15601  Call of Duty: Modern Warfare Trilogy  ...        0.00          0.02
# 15804  15807  Call of Duty: Modern Warfare Trilogy  ...        0.00          0.02
# ...

# %%
df3 = df3[df3['Platform'].str.match('X')].sort_values('Global_Sales')[::-1].head(5)
df3
# Out:
#     Rank                            Name  ... Other_Sales  Global_Sales
# 29    30  Call of Duty: Modern Warfare 3  ...        1.32         14.76
# 31    32         Call of Duty: Black Ops  ...        1.13         14.64
# 35    36      Call of Duty: Black Ops II  ...        1.12         13.73
# 36    37  Call of Duty: Modern Warfare 2  ...        1.29         13.51
# 61    62            Call of Duty: Ghosts  ...        0.82         10.21
#
# [5 rows x 11 columns]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=df3['Name'],y=df3['Global_Sales'])

# %%
#23 สร้าง Line Graph แสดงรายได้จาก North America จากปีแรกถึงปีสุดท้าย
df4 = df.sort_values('Year')
df4
# Out:
#         Rank                         Name  ... Other_Sales  Global_Sales
# 6896    6898                     Checkers  ...        0.00          0.24
# 2669    2671                       Boxing  ...        0.01          0.77
# 5366    5368                      Freeway  ...        0.00          0.34
# 1969    1971                     Defender  ...        0.01          1.05
# 1766    1768                      Kaboom!  ...        0.01          1.15
# ...      ...                          ...  ...         ...           ...
# 16307  16310                Freaky Flyers  ...        0.00          0.01
# 16327  16330                    Inversion  ...        0.00          0.01
# 16366  16369  Hakuouki: Shinsengumi Kitan  ...        0.00          0.01
# 16427  16430                 Virtua Quest  ...        0.00          0.01
# 16493  16496                   The Smurfs  ...        0.00          0.01
#
# [16598 rows x 11 columns]

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df4['Year'],y=df4['NA_Sales'])

# %%
#24 สร้าง Stripplot โดยให้แกน X เป็น Genre และ แกน Y เป็นรายได้ทั่วโลก
plt.figure(figsize=(15,5))
sns.stripplot(x=df['Genre'],y=df['Global_Sales'])

# %%
#25 สร้าง Distribution Plot ของปี
plt.figure(figsize=(15,5))
sns.distplot(df['Year'])

# %%
#26 สร้าง Bar Plot แสดงรายได้รวมในญี่ปุ่นรายปี
plt.figure(figsize=(25,5))
sns.barplot(x=df['Year'],y=df['JP_Sales'])
